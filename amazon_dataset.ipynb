# %% [markdown]
# <a href="https://colab.research.google.com/github/HarikishorAkula/Amazon-India-Dataset/blob/main/amazon_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## AMAZON INDIA DATA ANALYSIS

# %% [markdown]
# BUSINESS PROBLEM UNDERSTANDING

# %% [markdown]
# “Amazon wants to understand customer buying behavior and improve sales by analyzing product performance, customer reviews, and ratings to identify what drives purchases and satisfaction.”

# %% [markdown]
# Load the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the Dataset

# %%
dfs=pd.read_excel("/content/Amazon Data Sample.xlsx")
dfs.head()
# Out:
#    Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 0       1  IN-2013-BP1123058-41329 2013-02-24 2013-02-24        Same Day
# 1       2  IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 2       3  IN-2015-VG2180558-42273 2015-09-26 2015-09-28    Second Class
# 3       4  IN-2015-SW2027558-42125 2015-05-01 2015-05-01        Same Day
# 4       5  IN-2013-SG2047058-41424 2013-05-30 2013-05-31     First Class
#
#   Customer ID       Customer Name      Segment  Postal Code  \
# 0  BP-1123058  Benjamin Patterson     Consumer       500811
# 1  BF-1100558         Barry Franz  Home Office       499992
# 2  VG-2180558         Vivek Grady    Corporate       500868
# 3  SW-2027558    Scott Williamson     Consumer       500178
# 4  SG-2047058        Sheri Gordon     Consumer       499706
#
#                  City  ...   Product ID    Category Sub-Category  \
# 0               Surat  ...  FUR-CH-5443   Furniture       Chairs
# ...

# %% [markdown]
# knowing the Rows and columns

# %%
dfs.shape
# Out:
# (512, 24)

# %% [markdown]
# Information about the dataset

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          512 non-null    int64
#  1   Order ID        512 non-null    object
#  2   Order Date      512 non-null    datetime64[ns]
#  3   Ship Date       512 non-null    datetime64[ns]
#  4   Ship Mode       512 non-null    object
#  5   Customer ID     512 non-null    object
#  6   Customer Name   512 non-null    object
#  7   Segment         512 non-null    object
#  8   Postal Code     512 non-null    int64
#  9   City            512 non-null    object
#  10  State           512 non-null    object
#  11  Country         512 non-null    object
#  12  Region          512 non-null    object
#  13  Market          512 non-null    object
#  14  Product ID      512 non-null    object
#  15  Category        512 non-null    object
#  16  Sub-Category    512 non-null    object
# ...

# %% [markdown]
# finding Null values in the dataset

# %%
dfs.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Postal Code       0
# City              0
# State             0
# Country           0
# Region            0
# Market            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %% [markdown]
# here describing the data

# %%
dfs.describe()
# Out:
#            Row ID                  Order Date                      Ship Date  \
# count  512.000000                         512                            512
# mean   256.218750  2014-06-02 18:05:37.500000  2014-06-06 11:17:48.750000128
# min      1.000000         2012-02-16 00:00:00            2012-02-21 00:00:00
# 25%    128.750000         2013-06-21 06:00:00            2013-06-26 00:00:00
# 50%    256.500000         2014-08-06 00:00:00            2014-08-11 12:00:00
# 75%    384.250000         2015-06-06 00:00:00            2015-06-08 12:00:00
# max    500.000000         2015-12-31 00:00:00            2016-01-05 00:00:00
# std    147.480175                         NaN                            NaN
#
#          Postal Code        Sales    Quantity    Discount       Profit  \
# count     512.000000   512.000000  512.000000  512.000000   512.000000
# mean   500208.441406   897.999844    4.527344    0.014648   194.718457
# ...

# %%
dfd=dfs
dfd.head()
# Out:
#    Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 0       1  IN-2013-BP1123058-41329 2013-02-24 2013-02-24        Same Day
# 1       2  IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 2       3  IN-2015-VG2180558-42273 2015-09-26 2015-09-28    Second Class
# 3       4  IN-2015-SW2027558-42125 2015-05-01 2015-05-01        Same Day
# 4       5  IN-2013-SG2047058-41424 2013-05-30 2013-05-31     First Class
#
#   Customer ID       Customer Name      Segment  Postal Code  \
# 0  BP-1123058  Benjamin Patterson     Consumer       500811
# 1  BF-1100558         Barry Franz  Home Office       499992
# 2  VG-2180558         Vivek Grady    Corporate       500868
# 3  SW-2027558    Scott Williamson     Consumer       500178
# 4  SG-2047058        Sheri Gordon     Consumer       499706
#
#                  City  ...   Product ID    Category Sub-Category  \
# 0               Surat  ...  FUR-CH-5443   Furniture       Chairs
# ...

# %%
dfd.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Postal Code       0
# City              0
# State             0
# Country           0
# Region            0
# Market            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
dfd[dfd.isnull().any(axis=1)]
dfd.head()
# Out:
#    Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 0       1  IN-2013-BP1123058-41329 2013-02-24 2013-02-24        Same Day
# 1       2  IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 2       3  IN-2015-VG2180558-42273 2015-09-26 2015-09-28    Second Class
# 3       4  IN-2015-SW2027558-42125 2015-05-01 2015-05-01        Same Day
# 4       5  IN-2013-SG2047058-41424 2013-05-30 2013-05-31     First Class
#
#   Customer ID       Customer Name      Segment  Postal Code  \
# 0  BP-1123058  Benjamin Patterson     Consumer       500811
# 1  BF-1100558         Barry Franz  Home Office       499992
# 2  VG-2180558         Vivek Grady    Corporate       500868
# 3  SW-2027558    Scott Williamson     Consumer       500178
# 4  SG-2047058        Sheri Gordon     Consumer       499706
#
#                  City  ...   Product ID    Category Sub-Category  \
# 0               Surat  ...  FUR-CH-5443   Furniture       Chairs
# ...

# %% [markdown]
# dropping null values

# %%
dfd.dropna(inplace=True)

# %% [markdown]
# sales column value and their counts

# %%
dfd['Sales'].value_counts()
# Out:
# Sales
# 200.76    3
# 434.16    3
# 166.14    2
# 514.53    2
# 179.88    2
#          ..
# 697.32    1
# 682.95    1
# 414.72    1
# 863.31    1
# 566.40    1
# Name: count, Length: 478, dtype: int64

# %%
c=dfd.columns
c
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# getting all column values and their counts

# %%
for i in c:
  print("value_counts for {i}")
  print(dfd[i].value_counts())
  print('____')
# Out:
# value_counts for {i}
# Row ID
# 494    2
# 495    2
# 496    2
# 500    2
# 497    2
#       ..
# 161    1
# 160    1
# 159    1
# 158    1
# 173    1
# Name: count, Length: 500, dtype: int64
# ____
# value_counts for {i}
# Order ID
# IN-2015-BF1100558-42319    4
# IN-2015-VG2180558-42273    4
# IN-2013-BW1111058-41404    4
# IN-2014-LS1697558-41989    4
# IN-2014-AG1090058-41661    4
#                           ..
# IN-2015-GK1462058-42307    1
# IN-2012-KB1660058-41136    1
# IN-2014-CA1277558-41802    1
# IN-2013-EM1381058-41308    1
# IN-2015-MH1811558-42157    1
# Name: count, Length: 373, dtype: int64
# ____
# value_counts for {i}
# Order Date
# 2015-09-26    7
# 2014-08-12    5
# 2015-06-18    5
# 2012-10-05    5
# 2014-11-25    5
#              ..
# 2014-05-03    1
# 2014-12-13    1
# 2014-07-31    1
# 2015-11-08    1
# 2015-09-06    1
# Name: count, Length: 323, dtype: int64
# ____
# value_counts for {i}
# Ship Date
# 2014-12-20    6
# 2013-10-09    6
# 2012-10-09    5
# ...

# %%
dfd.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# Dropping Order id,Product ID,postal code,customer name,customer id, because it is a unwanted data columns

# %%
dfd.drop(['Order ID'],axis=1,inplace=True)

# %%
dfd.drop(['Product ID'],axis=1,inplace=True)

# %%
dfd.drop(['Postal Code','Customer Name','Customer ID'],axis=1,inplace=True)

# %%
dfd.shape
# Out:
# (512, 19)

# %% [markdown]
# dropping market columns

# %%
dfd.drop(['Market'],axis=1,inplace=True)

# %%
dfd.columns
# Out:
# Index(['Row ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Segment', 'City',
#        'State', 'Country', 'Region', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# Region wise Sales

# %%
plt.bar(x='Region',height='Sales',data=dfd)
# Out:
# <BarContainer object of 512 artists>

# %% [markdown]
# East Region has more Sales

# %% [markdown]
# Category wise Sales

# %%
plt.bar(data=dfd,x='Category',height='Sales')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('Sales by Category')
plt.show()

# %% [markdown]
# Technology Category is more Sales than other

# %%
dfd.columns
# Out:
# Index(['Row ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Segment', 'City',
#        'State', 'Country', 'Region', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
cate_sales=dfd.groupby('Category')['Sales'].sum()

# %% [markdown]
# here grouping the category and sales columns

# %%
plt.pie(cate_sales,labels=cate_sales.index,autopct='%1.1f%%',startangle=90,colors=['green','yellow','orange'])
plt.show()

# %% [markdown]
# Technology has more percentage of sales than other categories

# %% [markdown]
# Ship mode wise Sales

# %%
ship_modess=dfd.groupby('Ship Mode')['Sales'].sum()

# %%
plt.pie(ship_modess.values,labels=ship_modess.index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Standard class is more shipping than  than others

# %%
sns.histplot(data=dfd,x='Sales',bins=30,kde=True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# Here we understand that 100 to 1000 are more sales count

# %%
plt.scatter(x='Sales',y='Profit',data=dfd)
plt.xlabel('sales')
plt.ylabel('profit')
# Out:
# Text(0, 0.5, 'profit')

# %% [markdown]
# Here we understand that if Sales increase Profit Increases

# %%
dfd['Profit']=dfd['Profit'].round(1)
dfd['Profit'].head()
# Out:
# 0     582.4
# 1     632.5
# 2    2097.0
# 3     500.0
# 4     732.7
# Name: Profit, dtype: float64

# %%
sns.countplot(x='Order Priority',data=dfd,)
# Out:
# <Axes: xlabel='Order Priority', ylabel='count'>

# %% [markdown]
# Here order Priority is medium counts

# %%
sns.barplot(x='Category',y='Order Priority',data=dfd)
# Out:
# <Axes: xlabel='Category', ylabel='Order Priority'>

# %%
dfd['Category'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# Technology has more orders

# %%
sns.heatmap(dfd.corr(numeric_only=True),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Here Understanding the correlation

# %% [markdown]
# dropping row id

# %%
dfd.drop(['Row ID'],axis=1,inplace=True)

# %%
sns.barplot(x='State', y='Sales', data=dfd)
plt.xlabel('State')
plt.ylabel('Sales')
plt.title('Sales by State')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Manipur State  has more amazon sales

# %%
dfd['Profit'].mean()
# Out:
# np.float64(194.71835937500003)

# %%
# Highest priced product
highest = dfd.loc[dfd['Profit'].idxmax()]
print("💎 Highest Priced Product:\n", highest)

# Lowest priced product
lowest = dfd.loc[dfd['Profit'].idxmin()]
print("\n🪙 Lowest Priced Product:\n", lowest)
# Out:
# 💎 Highest Priced Product:
#  Order Date                      2014-06-12 00:00:00
# Ship Date                       2014-06-17 00:00:00
# Ship Mode                            Standard Class
# Segment                                    Consumer
# City                                           Kota
# State                                  Chhattisgarh
# Country                                       India
# Region                                         East
# Category                                 Technology
# Sub-Category                                 Phones
# Product Name      Apple Smart Phone, with Caller ID
# Sales                                       5751.54
# Quantity                                          9
# Discount                                        0.0
# Profit                                       2818.0
# Shipping Cost                                353.85
# Order Priority                               Medium
# ...

# %%
top_categories = dfd.groupby('Segment')['Profit'].sum().sort_values(ascending=False).head(10)
print("💼 Top 10 Categories by Total Profit:")
print(top_categories)
# Out:
# 💼 Top 10 Categories by Total Profit:
# Segment
# Consumer       50514.9
# Corporate      28734.3
# Home Office    20446.6
# Name: Profit, dtype: float64

# %%
plt.bar(x='Segment',height='Sales',data=dfd)
# Out:
# <BarContainer object of 512 artists>

# %% [markdown]
# Here consumer segment has more sales

# %%
top_categories.plot(kind='bar', color='skyblue', figsize=(8,4))
plt.title("Top Categories by Profit")
plt.ylabel("Total Profit")
plt.show()

# %% [markdown]
# consumer segment is more sales

# %%
top_cat=dfd.groupby('Category')['Profit'].sum().sort_values(ascending=False).head(10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x=top10_categories.values, y=top10_categories.index)
plt.title("Top 10 Categories by Profit")
plt.xlabel("Total Profit")
plt.ylabel("Category")
plt.show()

# %% [markdown]
# Here we do label Encoding because Categorical columns converted into numeric values

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in dfd.select_dtypes(include=['object']).columns:
  dfd[col]=le.fit_transform(dfd[col])

# %%
dfd.head()
# Out:
#   Order Date  Ship Date  Ship Mode  Segment  City  State  Country  Region  \
# 0 2013-02-24 2013-02-24          1        0   104      6        0       3
# 1 2015-11-11 2015-11-15          3        2    42      7        0       1
# 2 2015-09-26 2015-09-28          2        1   107     11        0       2
# 3 2015-05-01 2015-05-01          1        0    56      9        0       1
# 4 2013-05-30 2013-05-31          0        0    20     12        0       1
#
#    Category  Sub-Category  Product Name    Sales  Quantity  Discount  Profit  \
# 0         0             5           288  1878.72         4       0.0   582.4
# 1         2            11           256  4518.78         7       0.0   632.5
# 2         0             4           358  5667.87        13       0.0  2097.0
# 3         2             9           230  2174.13         7       0.0   500.0
# 4         2             6           189  1526.52         4       0.0   732.7
#
#    Shipping Cost  Order Priority  profit_margin
# ...

# %%
for col in dfd.select_dtypes(include=['object']).columns:
  dfd['col']=le.fit_transform(dfd['col'])

# %%
dfd.head()
# Out:
#   Order Date  Ship Date  Ship Mode  Segment  City  State  Country  Region  \
# 0 2013-02-24 2013-02-24          1        0   104      6        0       3
# 1 2015-11-11 2015-11-15          3        2    42      7        0       1
# 2 2015-09-26 2015-09-28          2        1   107     11        0       2
# 3 2015-05-01 2015-05-01          1        0    56      9        0       1
# 4 2013-05-30 2013-05-31          0        0    20     12        0       1
#
#    Category  Sub-Category  Product Name    Sales  Quantity  Discount  Profit  \
# 0         0             5           288  1878.72         4       0.0   582.4
# 1         2            11           256  4518.78         7       0.0   632.5
# 2         0             4           358  5667.87        13       0.0  2097.0
# 3         2             9           230  2174.13         7       0.0   500.0
# 4         2             6           189  1526.52         4       0.0   732.7
#
#    Shipping Cost  Order Priority  profit_margin
# ...

# %%
dfd.shape
# Out:
# (512, 18)

# %% [markdown]
# Here training the model without Profit and the target is Profit

# %%
x=dfd.drop(['Profit'],axis=1)
y=dfd['Profit']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Here we split the data into train and testing and traing is 80% data and testing is 20%

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Here we remove the date columns

# %%
dfd=dfd.select_dtypes(exclude=['datetime64[ns]'])

# %%
Lr=LinearRegression()
Lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=Lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,accuracy_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.782405721888138

# %% [markdown]
# Linear Model got 78% percent accuracy

# %%
ma=mean_absolute_error(y_test,y_pred)
print(round(ms,2))
# Out:
# 20762.73

# %% [markdown]
# error is 20k near

# %%
ms=mean_squared_error(y_test,y_pred)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", round(mse, 2))
print("R² Score:", round(r2, 2))
# Out:
# Mean Squared Error: 20762.73
# R² Score: 0.78

# %% [markdown]
# Finally we got 78 %

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred, color='blue')
plt.xlabel("Actual Profit")
plt.ylabel("Predicted Profit")
plt.title("Actual vs Predicted Profit")
plt.show()

# %% [markdown]
# In this Diagram we observe the model predicted 78 percent

# %%
comp=pd.DataFrame({'actual':y_test,'Predicted':'y_pred'})
comp
# Out:
#      actual Predicted
# 304   278.4    y_pred
# 495    88.7    y_pred
# 439   145.5    y_pred
# 153    70.7    y_pred
# 497    27.9    y_pred
# ..      ...       ...
# 396    85.1    y_pred
# 167   204.9    y_pred
# 275   250.8    y_pred
# 503   210.9    y_pred
# 507    88.7    y_pred
#
# [103 rows x 2 columns]

# %%
Q1 = dfd['Profit'].quantile(0.25)
Q3 = dfd['Profit'].quantile(0.75)
IQR = Q3 - Q1
dfd = dfd[(dfd['Profit'] >= Q1 - 1.5*IQR) & (dfd['Profit'] <= Q3 + 1.5*IQR)]

# %%
dfd
# Out:
#      Ship Mode  Segment  City  State  Country  Region  Category  Sub-Category  \
# 3            1        0    56      9        0       1         2             9
# 5            2        1    34      5        0       1         0            14
# 7            1        0    83     23        0       1         0             5
# 8            2        1    34      5        0       1         2            11
# 9            0        1   115      6        0       3         2             6
# ..         ...      ...   ...    ...      ...     ...       ...           ...
# 507          3        2   113     12        0       1         0             4
# 508          2        1   107     11        0       2         2             0
# 509          0        0    48     20        0       2         1            13
# 510          0        0    35     12        0       1         2             6
# 511          3        0    94      4        0       0         0             5
#
# ...

# %% [markdown]
# Here we Train Random Forest Regressor for better prediction

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=42)
rf.fit(x, y)

importances = pd.Series(rf.feature_importances_, index=x.columns)
print(importances.sort_values(ascending=False))
# Out:
# Sales             0.602481
# profit_margin     0.343531
# Shipping Cost     0.024201
# Quantity          0.006072
# Product Name      0.005957
# Region            0.004459
# City              0.003369
# State             0.002927
# Sub-Category      0.002130
# Order Priority    0.001362
# Category          0.001189
# Segment           0.001108
# Ship Mode         0.001095
# Discount          0.000120
# Country           0.000000
# dtype: float64

# %%
re=RandomForestRegressor(n_estimators=200,random_state=42)
re.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
k=re.predict(x_test)

# %%
r2_score(y_test,k)
# Out:
# 0.9622710495266703

# %%
mean_absolute_error(y_test,k)
# Out:
# 23.505587378640758

# %%
mean_squared_error(y_test,k)
# Out:
# 3600.0768529635807

# %% [markdown]
# Here random Forest got 96 % the model predicted very good

# %%
from xgboost import XGBRegressor
xg=XGBRegressor(n_estimators=1000,learning_rate=0.20,max_depth=6,random_state=42)
xg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgs=xg.predict(x_test)
r2_score(y_test,xgs)
# Out:
# 0.87753581714781

# %% [markdown]
# Here Xg boost predict 87% the model is good prediction

# %%
mean_absolute_error(y_test,xgs)
# Out:
# 30.384437605941184

# %%
mean_squared_error(y_test,xgs)
# Out:
# 11064.973937007418

# %% [markdown]
# Finally WE observe that Random Forest Algorithm is predicting better than Linear Regression,Xg boost .the Random forest got 96 % because it is robust to outliers

# %% [markdown]
# FInally in these Dataset We observe that EAST region has More Sales and Technology category is selling More Items
